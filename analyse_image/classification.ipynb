# %%
import pandas as pnd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras

tf.config.set_visible_devices([], 'GPU')

#Définition de la longueur et de la largeur de l'image
LONGUEUR_IMAGE = 28
LARGEUR_IMAGE = 28

#Chargement des images
observations_entrainement = pnd.read_csv('datas/fashion-mnist_train.csv')
# Out:
# /Users/ayahafiane/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
#On exclut la première colonne (les labels) pour constituer un tableau de pixels
X = np.array(observations_entrainement.iloc[:, 1:])

premiereImage = X[0]
premiereImage = premiereImage.reshape([LONGUEUR_IMAGE,LARGEUR_IMAGE])
plt.imshow(premiereImage)
plt.show()

# %%
#On crée des catégories à l'aide du module Keras
y = keras.utils.to_categorical(np.array(observations_entrainement.iloc[:,0]))
#Répartition des données d'entrainement en données d'apprentissage et données de validation
#80% de donnée d'apprentissage et 20% de donnée de validation
X_apprentissage, X_validation, y_apprentissage, y_validation = train_test_split(X, y, test_size=0.2, random_state=13)

# %%
# On redimensionne les images au format 28*28 et on réalise un scaling sur les données des pixels
X_apprentissage = X_apprentissage.reshape(X_apprentissage.shape[0], 
                                          LARGEUR_IMAGE, 
                                          LONGUEUR_IMAGE, 1)
X_apprentissage = X_apprentissage.astype('float32')
X_apprentissage /= 255

X_validation = X_validation.reshape(X_validation.shape[0], 
                                    LARGEUR_IMAGE, 
                                    LONGUEUR_IMAGE, 1)
X_validation = X_validation.astype('float32')
X_validation /= 255

# %%
#Preparation des données de tests
observations_test = pnd.read_csv('datas/fashion-mnist_test.csv')
X_test = np.array(observations_test.iloc[:, 1:])
y_test = tf.keras.utils.to_categorical(np.array(observations_test.iloc[:, 0]))
X_test = X_test.reshape(X_test.shape[0], 
                        LARGEUR_IMAGE, 
                        LONGUEUR_IMAGE, 1)
X_test = X_test.astype('float32')
X_test /= 255

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Input
from keras.layers import Conv2D, MaxPooling2D

# On spécifie les dimensions de l'image d'entrée
dimentionImage = (LARGEUR_IMAGE, LONGUEUR_IMAGE, 1)

# On crée le réseau de neurones couche par couche
reseauNeurone1Convolution = Sequential()

# Ajout de la couche d'entrée
reseauNeurone1Convolution.add(Input(shape=dimentionImage))

#1- Ajout de la couche de convolution comportant
# 32 filtres de de taille 3x3 (Kernel) parcourant l'image
# Une fonction d'activation de type ReLU (Rectified Linear Activation)
# Une image d'entrée de 28px * 28 px 
reseauNeurone1Convolution.add(Conv2D(32, 
                                     kernel_size=(3, 3), 
                                     activation='relu'))

#2- Définition de la fonction de pooling avec une fenêtre de 2px sur 2 px
reseauNeurone1Convolution.add(MaxPooling2D(pool_size=(2, 2)))

#3- Ajout d'une fonction d'ignorance
reseauNeurone1Convolution.add(Dropout(0.2))

#5 - On transforme en une seule ligne
reseauNeurone1Convolution.add(Flatten())

#6 - Ajout d'un réseau de neurones composé de 128 neurones avec 
# une fonction d'activation de type ReLU
reseauNeurone1Convolution.add(Dense(128, activation='relu'))

#7 - Ajout d'un réseau de neurones composé de 10 neurones avec une 
# fonction d'activation de type softmax
reseauNeurone1Convolution.add(Dense(10, activation='softmax'))

# %%
reseauNeurone1Convolution.compile(loss=keras.losses.categorical_crossentropy, 
                                  optimizer=tf.keras.optimizers.Adam(), 
                                  metrics=['accuracy'])

# %%
historique_apprentissage = reseauNeurone1Convolution.fit(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256,
    epochs=10,
    verbose=1,
    validation_data=(X_validation, y_validation))
# Out:
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.7349 - loss: 0.7759 - val_accuracy: 0.8686 - val_loss: 0.3800
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8718 - loss: 0.3675 - val_accuracy: 0.8862 - val_loss: 0.3232
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - accuracy: 0.8900 - loss: 0.3105 - val_accuracy: 0.8964 - val_loss: 0.2954
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.8987 - loss: 0.2814 - val_accuracy: 0.9015 - val_loss: 0.2821
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.9079 - loss: 0.2590 - val_accuracy: 0.9032 - val_loss: 0.2692
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.9135 - loss: 0.2408 - val_accuracy: 0.9005 - val_loss: 0.2766
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.9198 - loss: 0.2262 - val_accuracy: 0.9057 - val_loss: 0.2623
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9241 - loss: 0.2168 - val_accuracy: 0.9104 - val_loss: 0.2469
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.9258 - loss: 0.2038 - val_accuracy: 0.9079 - val_loss: 0.2560
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.9308 - loss: 0.1936 - val_accuracy: 0.9129 - val_loss: 0.2399

# %%
evaluation = reseauNeurone1Convolution.evaluate(X_test, y_test, verbose=0)
print('Erreur:', evaluation[0])
print('Précision:', evaluation[1])
# Out:
# Erreur: 0.2305029332637787
# Précision: 0.9204999804496765

# %%
plt.plot(historique_apprentissage.history['accuracy'])
plt.plot(historique_apprentissage.history['val_accuracy'])
plt.title('Précision du modèle')
plt.ylabel('Précision')
plt.xlabel('Epoch')
plt.legend(['Apprentissage', 'Test'], loc='upper left')
plt.show()
# Plot training & validation loss values
plt.plot(historique_apprentissage.history['loss'])
plt.plot(historique_apprentissage.history['val_loss'])
plt.title('Erreur')
plt.ylabel('Erreur')
plt.xlabel('Epoch')
plt.legend(['Apprentissage', 'Test'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

generateur_images = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    shear_range=0.3,
    height_shift_range=0.08,
    zoom_range=0.08)

# %%
nouvelles_images_apprentissage = generateur_images.flow(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256)

nouvelles_images_validation = generateur_images.flow(
    X_validation, 
    y_validation,
    batch_size=256)

historique_apprentissage = reseauNeurone1Convolution.fit(
    nouvelles_images_apprentissage,
    steps_per_epoch=48000//256,
    epochs=50,
    validation_data=nouvelles_images_validation,
    validation_steps=12000//256,
    verbose=1 )

evaluation = reseauNeurone1Convolution.evaluate(X_test, y_test, verbose=0)

print('Erreur :', evaluation[0])
print('Précision:', evaluation[1])
# Out:
# /Users/ayahafiane/Library/Python/3.9/lib/python/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.8141 - loss: 0.4998 - val_accuracy: 0.8510 - val_loss: 0.4089
# Epoch 2/50
#   1/187 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.8359 - loss: 0.3969
# /Users/ayahafiane/Library/Python/3.9/lib/python/site-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8359 - loss: 0.3969 - val_accuracy: 0.8509 - val_loss: 0.4061
# Epoch 3/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.8487 - loss: 0.4095 - val_accuracy: 0.8511 - val_loss: 0.3957
# Epoch 4/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8711 - loss: 0.3313 - val_accuracy: 0.8586 - val_loss: 0.3848
# Epoch 5/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.8513 - loss: 0.3965 - val_accuracy: 0.8665 - val_loss: 0.3625
# Epoch 6/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8438 - loss: 0.3587 - val_accuracy: 0.8641 - val_loss: 0.3696
# Epoch 7/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.8622 - loss: 0.3714 - val_accuracy: 0.8635 - val_loss: 0.3702
# Epoch 8/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8906 - loss: 0.3543 - val_accuracy: 0.8667 - val_loss: 0.3607
# Epoch 9/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.8698 - loss: 0.3499 - val_accuracy: 0.8746 - val_loss: 0.3500
# Epoch 10/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8477 - loss: 0.3375 - val_accuracy: 0.8708 - val_loss: 0.3469
# Epoch 11/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - accuracy: 0.8682 - loss: 0.3507 - val_accuracy: 0.8741 - val_loss: 0.3447
# Epoch 12/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8555 - loss: 0.3876 - val_accuracy: 0.8742 - val_loss: 0.3387
# Epoch 13/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - accuracy: 0.8741 - loss: 0.3375 - val_accuracy: 0.8787 - val_loss: 0.3316
# Epoch 14/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8633 - loss: 0.3782 - val_accuracy: 0.8754 - val_loss: 0.3355
# Epoch 15/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.8761 - loss: 0.3377 - val_accuracy: 0.8775 - val_loss: 0.3352
# Epoch 16/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8438 - loss: 0.3637 - val_accuracy: 0.8793 - val_loss: 0.3264
# Epoch 17/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.8811 - loss: 0.3185 - val_accuracy: 0.8838 - val_loss: 0.3178
# Epoch 18/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8711 - loss: 0.3663 - val_accuracy: 0.8812 - val_loss: 0.3263
# Epoch 19/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.8808 - loss: 0.3214 - val_accuracy: 0.8842 - val_loss: 0.3175
# Epoch 20/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8906 - loss: 0.2939 - val_accuracy: 0.8764 - val_loss: 0.3260
# Epoch 21/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.8836 - loss: 0.3147 - val_accuracy: 0.8835 - val_loss: 0.3161
# Epoch 22/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8789 - loss: 0.3460 - val_accuracy: 0.8808 - val_loss: 0.3189
# Epoch 23/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.8835 - loss: 0.3119 - val_accuracy: 0.8861 - val_loss: 0.3069
# Epoch 24/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9570 - loss: 0.1832 - val_accuracy: 0.8821 - val_loss: 0.3130
# Epoch 25/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.8872 - loss: 0.3041 - val_accuracy: 0.8827 - val_loss: 0.3092
# Epoch 26/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8516 - loss: 0.3653 - val_accuracy: 0.8859 - val_loss: 0.3103
# Epoch 27/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.8857 - loss: 0.3085 - val_accuracy: 0.8864 - val_loss: 0.3046
# Epoch 28/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9258 - loss: 0.2552 - val_accuracy: 0.8897 - val_loss: 0.2997
# Epoch 29/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.8860 - loss: 0.3030 - val_accuracy: 0.8877 - val_loss: 0.3046
# Epoch 30/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8867 - loss: 0.3099 - val_accuracy: 0.8874 - val_loss: 0.2996
# Epoch 31/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.8908 - loss: 0.2966 - val_accuracy: 0.8860 - val_loss: 0.3070
# Epoch 32/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9062 - loss: 0.2533 - val_accuracy: 0.8832 - val_loss: 0.3095
# Epoch 33/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - accuracy: 0.8872 - loss: 0.2992 - val_accuracy: 0.8897 - val_loss: 0.3037
# Epoch 34/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8828 - loss: 0.3170 - val_accuracy: 0.8939 - val_loss: 0.2923
# Epoch 35/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.8910 - loss: 0.2915 - val_accuracy: 0.8833 - val_loss: 0.3105
# Epoch 36/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8672 - loss: 0.3785 - val_accuracy: 0.8895 - val_loss: 0.2969
# Epoch 37/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.8907 - loss: 0.2942 - val_accuracy: 0.8929 - val_loss: 0.2984
# Epoch 38/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8594 - loss: 0.2937 - val_accuracy: 0.8913 - val_loss: 0.2906
# Epoch 39/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.8937 - loss: 0.2875 - val_accuracy: 0.8913 - val_loss: 0.2988
# Epoch 40/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9180 - loss: 0.2387 - val_accuracy: 0.8903 - val_loss: 0.2985
# Epoch 41/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.8944 - loss: 0.2874 - val_accuracy: 0.8910 - val_loss: 0.2938
# Epoch 42/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8984 - loss: 0.2975 - val_accuracy: 0.8892 - val_loss: 0.2910
# Epoch 43/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.8942 - loss: 0.2823 - val_accuracy: 0.8984 - val_loss: 0.2821
# Epoch 44/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9141 - loss: 0.1990 - val_accuracy: 0.8972 - val_loss: 0.2845
# Epoch 45/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.8933 - loss: 0.2797 - val_accuracy: 0.8916 - val_loss: 0.2934
# Epoch 46/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8594 - loss: 0.3262 - val_accuracy: 0.8929 - val_loss: 0.2882
# Epoch 47/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.8974 - loss: 0.2764 - val_accuracy: 0.8916 - val_loss: 0.2943
# Epoch 48/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9062 - loss: 0.2823 - val_accuracy: 0.8928 - val_loss: 0.2888
# Epoch 49/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.8983 - loss: 0.2727 - val_accuracy: 0.8891 - val_loss: 0.2955
# Epoch 50/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8984 - loss: 0.2676 - val_accuracy: 0.8904 - val_loss: 0.2942
# Erreur : 0.23169273138046265
# Précision: 0.9178000092506409
