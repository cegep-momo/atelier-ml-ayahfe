# %%
import numpy as nmp
import pandas as pd

#Chargement du dataset avec pour séparateur des tabulations
dataset = pnd.read_csv("datas/dataset.csv",delimiter='\t')

#Suppression des lignes ayant des valeurs manquantes
dataset = dataset.dropna(axis=0, how='any')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 import pandas as pd  # (si ce n’est pas déjà fait plus haut)
#       4 #Chargement du dataset avec pour séparateur des tabulations
# ----> 5 dataset = pnd.read_csv("datas/dataset.csv",delimiter='\t')
#       7 #Suppression des lignes ayant des valeurs manquantes
#       8 dataset = dataset.dropna(axis=0, how='any')
#
# NameError: name 'pnd' is not defined
